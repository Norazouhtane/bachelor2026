# %%
import sys, os
sys.path.append(os.path.abspath(".."))

import pandas as pd
from scripts.data_preparation_2004 import load_data as load_data_2004
from scripts.data_preparation_2023 import load_data as load_data_2023

# %% [markdown]
# ## Loading Data

# %%
west  = ["BE", "FR", "DE", "NL", "IE", "GR", "PT", "ES", "AT", "FI", "SE"]
east  = ["EE", "HU", "PL", "SK", "SI"]
all   = west + east

# %%
X_train, X_test, y_train, y_test, df = load_data_2004("../data/raw/ESS2.csv", "../codebooks/ESS2e03_6 codebook.html", all, 42)
# Out:
# /Users/norazouhtane/Downloads/bachelor2026/scripts/data_preparation_2004.py:19: DtypeWarning: Columns (165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path)
# 554 variables had non-response values

# %%
X_train, X_test, y_train, y_test, df = load_data_2023("../data/raw/ESS11.csv", "../codebooks/ESS11e04_1 codebook.html", all, 42)
# Out:
# /Users/norazouhtane/Downloads/bachelor2026/scripts/data_preparation_2023.py:19: DtypeWarning: Columns (192,198,666) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path)
# 525 variables had non-response values

# %%
X_train, X_test, y_train, y_test, df = load_data_2004("../data/raw/ESS2.csv", "../codebooks/ESS2e03_6 codebook.html", east, 42)
# Out:
# /Users/norazouhtane/Downloads/bachelor2026/scripts/data_preparation_2004.py:19: DtypeWarning: Columns (165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path)
# 554 variables had non-response values

# %%
X_train, X_test, y_train, y_test, df = load_data_2023("../data/raw/ESS11.csv", "../codebooks/ESS11e04_1 codebook.html", east, 42)
# Out:
# /Users/norazouhtane/Downloads/bachelor2026/scripts/data_preparation_2023.py:19: DtypeWarning: Columns (192,198,666) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path)
# 525 variables had non-response values

# %%
X_train, X_test, y_train, y_test, df = load_data_2004("../data/raw/ESS2.csv", "../codebooks/ESS2e03_6 codebook.html", west, 42)
# Out:
# /Users/norazouhtane/Downloads/bachelor2026/scripts/data_preparation_2004.py:19: DtypeWarning: Columns (165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path)
# 554 variables had non-response values

# %%
X_train, X_test, y_train, y_test, df = load_data_2023("../data/raw/ESS11.csv", "../codebooks/ESS11e04_1 codebook.html", west, 42)
# Out:
# /Users/norazouhtane/Downloads/bachelor2026/scripts/data_preparation_2023.py:19: DtypeWarning: Columns (192,198,666) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path)
# 525 variables had non-response values

# %% [markdown]
# ## Class Distribution

# %%
# Value Counts of Target Variable
print(pd.concat([y_train, y_test]).value_counts())
# Out:
# vote
# 1    15565
# 0     2971
# Name: count, dtype: int64

# %% [markdown]
# ## Missing Values

# %%
# Average NaNs per row
print(f"Average NaNs per row: {df.isnull().sum(axis=1).mean():.1f}")

# Top 20 columns with most NaNs
print(df.isnull().sum().sort_values(ascending=False).head(20))
# Out:
# Average NaNs per row: 13.8
# mnactp      23288
# prtcldse    23234
# livecnta    23194
# mainact     21945
# emplno      21356
# rlgdnme     21136
# uemp12m     18137
# uemp5yr     18110
# njbspv      17695
# pdjobyr     15958
# rlgblge     15240
# pdjobev     14142
# prtdgcl     14091
# crpdwk      13624
# eiscedp      9437
# rlgdnm       9318
# netustm      5479
# wrkctra      4644
# hinctnta     4539
# wkhct        3989
# dtype: int64
